# %%
import pandas as pd
df = pd.read_csv('Gross Withdrawals and Production.csv')
df
# Out:
#        period duoarea area-name product product-name process  \
# 0     2024-09     SMO    USA-MO    EPG0  Natural Gas     FGW
# 1     2024-09     SAL    USA-AL    EPG0  Natural Gas     FGC
# 2     2024-09     SMD    USA-MD    EPG0  Natural Gas     VGV
# 3     2024-09     SND    USA-ND    EPG0  Natural Gas     FGO
# 4     2024-09     SLA    USA-LA    EPG0  Natural Gas     FGO
# ...       ...     ...       ...     ...          ...     ...
# 4995  2023-08     SMD    USA-MD    EPG0  Natural Gas     FGO
# 4996  2023-08     SWY    USA-WY    EPG0  Natural Gas     FGG
# 4997  2023-08     SNE    USA-NE    EPG0  Natural Gas     FGG
# 4998  2023-08     SKS    USA-KS    EPG0  Natural Gas     FGG
# 4999  2023-08     SAK    USA-AK    EPG0  Natural Gas     VGM
#
#                         process-name                 series  \
# 0                  Gross Withdrawals               N9010MO2
# 1     Withdrawals from Coalbed Wells  NGM_EPG0_FGC_SAL_MMCF
# ...
