# %%
import pandas as pd
df = pd.read_csv('Natural Gas Plant Processing.csv')
df
# Out:
#        period duoarea area-name product product-name process     process-name  \
# 0     2024-09     NUS      U.S.    EPG0  Natural Gas     VG9  Extraction Loss
# 1     2024-08     NUS      U.S.    EPG0  Natural Gas     VG9  Extraction Loss
# 2     2024-07     NUS      U.S.    EPG0  Natural Gas     VG9  Extraction Loss
# 3     2024-06     NUS      U.S.    EPG0  Natural Gas     VG9  Extraction Loss
# 4     2024-05     NUS      U.S.    EPG0  Natural Gas     VG9  Extraction Loss
# ...       ...     ...       ...     ...          ...     ...              ...
# 4995  2005-07     SFL   FLORIDA    EPG0  Natural Gas     VG9  Extraction Loss
# 4996  2005-07     SND    USA-ND    EPG0  Natural Gas     VG9  Extraction Loss
# 4997  2005-07     SMT    USA-MT    EPG0  Natural Gas     VG9  Extraction Loss
# 4998  2005-07     SOK    USA-OK    EPG0  Natural Gas     VG9  Extraction Loss
# 4999  2005-07     SLA    USA-LA    EPG0  Natural Gas     VG9  Extraction Loss
#
# ...
